# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image_1 = cv2.imread("../data/image01.jpg")
image_2 = cv2.imread("../data/image05.jpg")

# %%
plt.imshow(image_1, cmap="gray")

# %%
pt = 255/2
max = 255
ret, thres_1 = cv2.threshold(image_1, pt, max, cv2.THRESH_BINARY)

# %%
plt.imshow(thres_1, cmap="gray")

# %%
plt.imshow(image_2, cmap="gray")

# %%
image_2 = cv2.imread("../data/image05.jpg")
pt = 80
ret, img_thres = cv2.threshold(image_2, pt, max, cv2.THRESH_BINARY_INV)
plt.imshow(img_thres, cmap="gray")

# %%
image_2 = cv2.imread("../data/image05.jpg")
pt = 255/2
ret, img_thres = cv2.threshold(image_2, pt, max, cv2.THRESH_BINARY)
plt.imshow(img_thres, cmap="gray")

# %%
image_2 = cv2.imread("../data/image05.jpg", 0)
# thres_gray = cv2.cvtColor(image_2, cv2.COLOR_BAYER_BG2GRAY)
th2 = cv2.adaptiveThreshold(image_2, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 5, 8)

# %%
plt.imshow(th2, cmap="gray")

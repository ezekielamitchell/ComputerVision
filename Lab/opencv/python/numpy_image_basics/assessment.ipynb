# %% [markdown]
# # NumPy and Image Assessment

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
arr = np.zeros((5,5), int)
arr[:]=10
arr
# Out:
# array([[10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10]])

# %%
np.random.seed(101)
arr = np.random.randint(low=0,high=100,size=(5,5))
print(np.max(arr))
print(np.min(arr))
# Out:
# 95
# 4

# %%
data_set = '/home/ezekiel/Developer/ComputerVision/Lab/opencv/data/images/'
image = cv2.imread(data_set + 'image00.jpg')
image_arr = np.asarray(image)
image_red = image_arr.copy()
image_green = image_arr.copy()
plt.imshow(image_arr[:,:,2], cmap='gray')

# %%
image_red[:,:,1]=0
image_red[:,:,2]=0
plt.imshow(image_red)

# %%
image_green = image_arr.copy()
image_green[:,:,2]=0
image_green[:,:,0]=0
plt.imshow(image_green)

# %%
image_blue = image_arr.copy()
image_blue[:,:,1]=0
image_blue[:,:,0]=0
plt.imshow(image_blue)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('../Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB -> R G B
# OPENCV -> B G R

# %%
# color conversion for opencv -> matplotlib
fixed_img = cv.cvtColor(img,cv.COLOR_BGR2RGB)

# %%
plt.imshow(fixed_img)

# %%
imgGray = cv.imread('../Computer-Vision-with-Python/DATA/00-puppy.jpg', cv.IMREAD_GRAYSCALE)

# %%
imgGray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(imgGray, cmap='gray')

# %%
plt.imshow(fixed_img)

# %%
fixed_img.shape
# Out:
# (1300, 1950, 3)

# %%
newImg = cv.resize(fixed_img, (1000,400))

# %%
plt.imshow(newImg)

# %%
w_ration = 0.5 # 50% 
h_ration = 0.5
newImg = cv.resize(fixed_img, (0,0),fixed_img,w_ration,h_ration)

# %%
plt.imshow(newImg)

# %%
newImg.shape
# Out:
# (650, 975, 3)

# %%
imgFlip = cv.flip(newImg,0) # use 1 for vertical flip, etc...

# %%
plt.imshow(imgFlip)

# %%
type(newImg)
# Out:
# numpy.ndarray

# %%
cv.imwrite('tester1.jpg', imgFlip)
# Out:
# True

# %%
plt.imshow(newImg)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(fixed_img)

# %% [markdown]
# # Section 5: Video Basics with Python and OpenCV
#
# Topics covered:
# - Introduction to Video Basics
# - Connecting to Camera
# - Using Video Files
# - Drawing on Live Camera
# - Video Basics Assessment
# - Video Basics Assessment Solutions

# %%
import cv2 as cv
import os
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = '../data/finger_move.mp4'

if os.path.exists(path):
    video = cv.VideoCapture(path)

    if not video.isOpened():
        print(f"Error: Cannot open {video}")
        print("Check: file exists, correct path, codec supported")
        exit()
    else:
        print('Video successfully captured...')

while video.isOpened():
    ret, frame = video.read()

    if ret:
        time.sleep(1/30)
        cv.imshow('frame', frame)

        if cv.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

video.release()
cv.destroyAllWindows()
# Out:
# Video successfully captured...

# %%
cap = cv.VideoCapture('..')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('../data/internal_external.png',0)
plt.imshow(img, cmap='gray')

# %%
img.shape
# Out:
# (652, 1080)

# %%
image, contours  = cv2.findContours(img, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

# %%
img = cv2.drawContours(image, contours, -1, (0,255,0), 2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 img = cv2.drawContours(image, contours, -1, (0,255,0), 2)
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'drawContours'
# > Overload resolution failed:
# >  - image is not a numerical tuple
# >  - Expected Ptr<cv::UMat> for argument 'image'

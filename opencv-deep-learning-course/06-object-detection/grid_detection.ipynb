# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
flat_chessboard = cv2.imread("../data/flat_chessboard.png")
flat_chessboard = cv2.cvtColor(flat_chessboard, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flat_chessboard)

# %%
found, corners = cv2.findChessboardCorners(flat_chessboard, (7,7))

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 43.500004,  43.500004]],
#
#        [[ 87.5     ,  43.5     ]],
#
#        [[131.5     ,  43.5     ]],
#
#        [[175.5     ,  43.5     ]],
#
#        [[219.5     ,  43.5     ]],
#
#        [[263.5     ,  43.5     ]],
#
#        [[307.5     ,  43.5     ]],
#
#        [[ 43.499996,  87.50001 ]],
#
#        [[ 87.5     ,  87.5     ]],
#
#        [[131.5     ,  87.5     ]],
#
#        [[175.5     ,  87.5     ]],
#
#        [[219.5     ,  87.5     ]],
#
#        [[263.5     ,  87.5     ]],
#
#        [[307.5     ,  87.49999 ]],
#
#        [[ 43.500004, 131.5     ]],
#
#        [[ 87.5     , 131.5     ]],
#
#        [[131.5     , 131.5     ]],
#
#        [[175.5     , 131.5     ]],
#
#        [[219.5     , 131.5     ]],
#
#        [[263.5     , 131.5     ]],
#
#        [[307.5     , 131.5     ]],
#
#        [[ 43.499996, 175.5     ]],
#
#        [[ 87.5     , 175.5     ]],
#
#        [[131.5     , 175.5     ]],
#
#        [[175.5     , 175.5     ]],
#
# ...

# %%
found_chessboard = cv2.drawChessboardCorners(flat_chessboard, (7,7), corners, found)

# %%
plt.imshow(flat_chessboard)

# %%
dots = cv2.imread('../data/dot_grid.png')

# %%
plt.imshow(dots)

# %%
found, corners = cv2.findCirclesGrid(dots, (10,10), cv2.CALIB_CB_SYMMETRIC_GRID)

# %%
plt.imshow(dots)

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 29.5,  29.5]],
#
#        [[ 89.5,  29.5]],
#
#        [[149.5,  29.5]],
#
#        [[209.5,  29.5]],
#
#        [[269.5,  29.5]],
#
#        [[329.5,  29.5]],
#
#        [[389.5,  29.5]],
#
#        [[449.5,  29.5]],
#
#        [[509.5,  29.5]],
#
#        [[569.5,  29.5]],
#
#        [[ 29.5,  89.5]],
#
#        [[ 89.5,  89.5]],
#
#        [[149.5,  89.5]],
#
#        [[209.5,  89.5]],
#
#        [[269.5,  89.5]],
#
#        [[329.5,  89.5]],
#
#        [[389.5,  89.5]],
#
#        [[449.5,  89.5]],
#
#        [[509.5,  89.5]],
#
#        [[569.5,  89.5]],
#
#        [[ 29.5, 149.5]],
#
#        [[ 89.5, 149.5]],
#
#        [[149.5, 149.5]],
#
#        [[209.5, 149.5]],
#
#        [[269.5, 149.5]],
#
#        [[329.5, 149.5]],
#
#        [[389.5, 149.5]],
#
#        [[449.5, 149.5]],
#
#        [[509.5, 149.5]],
#
#        [[569.5, 149.5]],
#
#        [[ 29.5, 209.5]],
#
#        [[ 89.5, 209.5]],
#
#        [[149.5, 209.5]],
#
#        [[209.5, 209.5]],
#
# ...

# %%
dots = cv2.drawChessboardCorners(dots, (10,10), corners, found)
plt.imshow(dots)
